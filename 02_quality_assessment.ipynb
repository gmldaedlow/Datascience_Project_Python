# %%
import pandas as pd
import re

# %%
# importing cleaned data + brands.csv
orders_cl = pd.read_parquet("orders_cl.parquet")
orderlines_cl = pd.read_parquet("orderlines_cl.parquet")
products_cl = pd.read_parquet("products_cl.parquet")
brands = pd.read_csv("brands.csv")

# %%
# define display format
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
#     orders –> Keep only orders with the states that you want to work with.
#     orderlines –> Keep only orders present in orders.
#     orders –> Keep only orders present in orderlines.

# %%
# Exclude unwanted orders
orders_cl.groupby("state").count()
# Out:
#                  order_id  created_date  total_paid
# state
# Cancelled            7233          7233        7233
# Completed           46605         46605       46605
# Pending             14374         14374       14374
# Place Order         40883         40883       40883
# Shopping Basket    117809        117809      117809

# %%
orders_cl=orders_cl.loc[orders_cl['state']=='Completed']

# %%
# fixing datatypes
orders_cl.loc[:,"created_date"] = pd.to_datetime(orders_cl.loc[:,"created_date"])

# %%
# orderlines –> Keep only orders present in orders
orders_order_ids = orders_cl["order_id"]
orderlines_cl = orderlines_cl[orderlines_cl["id_order"].isin(orders_order_ids)].copy()
orderlines_cl
# Out:
#              id  id_order  product_id  product_quantity        sku  \
# 7       1119116    299545           0                 1    OWC0100
# 8       1119119    299546           0                 1    IOT0014
# 9       1119120    295347           0                 1    APP0700
# 11      1119126    299549           0                 1    PAC0929
# 18      1119134    299556           0                 1  CRU0039-A
# ...         ...       ...         ...               ...        ...
# 293599  1649474    525664           0                 1    TUC0207
# 293616  1649512    527070           0                 2    APP0698
# 293621  1649522    527074           0                 2    APP0698
# 293644  1649565    527096           0                 3    APP0698
# 293661  1649593    527112           0                 1    APP0698
#
#         unit_price                date
# 7            47.49 2017-01-01 01:46:16
# 8            18.99 2017-01-01 01:50:34
# 9            72.19 2017-01-01 01:54:11
# 11         2565.99 2017-01-01 02:07:42
# 18           60.90 2017-01-01 02:20:14
# ...            ...                 ...
# 293599       16.52 2018-03-14 11:45:05
# 293616        9.99 2018-03-14 11:49:01
# 293621        9.99 2018-03-14 11:49:36
# 293644        9.99 2018-03-14 11:54:35
# 293661        9.99 2018-03-14 11:58:13
#
# [62103 rows x 7 columns]

# %%
# orders –> Keep only orders present in orderlines.
orderlines_order_ids = orderlines_cl["id_order"]
orders_cl = orders_cl[orders_cl["order_id"].isin(orderlines_order_ids)].copy()

# %%
# checking if that worked
orders_cl["order_id"].nunique() == orderlines_cl["id_order"].nunique()
# Out:
# True

# %%
# Exclude orders with unknown products
intersection = set(orders_cl.order_id).intersection(set(orderlines_cl.id_order))
orders_cl = orders_cl.loc[orders_cl.order_id.isin(intersection),:]

# %%
orders_cl["order_id"].nunique() == orderlines_cl.id_order.nunique()
# Out:
# True

# %%
# Exploring the revenue from different tables
orderlines_cl.loc[:,"unit_price_total"] = orderlines_cl.loc[:,"unit_price"] * orderlines_cl.loc[:,"product_quantity"]

# %%
# sum of unit_price_total
ol_grouped = orderlines_cl.groupby("id_order")["unit_price_total"].sum()

# %%
ol_grouped
# Out:
# id_order
# 241423   129.16
# 242832    10.77
# 243330    77.99
# 245275   149.00
# 245595   105.98
#           ...
# 527042    13.99
# 527070    19.98
# 527074    19.98
# 527096    29.97
# 527112     9.99
# Name: unit_price_total, Length: 45379, dtype: float64

# %%
# What is the average difference between total_paid and unit_price_total?
orders_diff = orders_cl.merge(ol_grouped, how="left", left_on="order_id", right_on="id_order")

# %%
# What is the average difference between total_paid and unit_price_total?
orders_diff.loc[:,"diff"] = orders_diff.loc[:,"total_paid"] - orders_diff.loc[:,"unit_price_total"]
orders_diff.loc[:,"diff"].mean()
# Out:
# 4.267111659578219

# %%
# What is the distribution of these differences?
orders_diff["diff"].describe()
# Out:
# count   45379.00
# mean        4.27
# std        25.03
# min      -165.00
# 25%         0.00
# 50%         4.99
# 75%         6.99
# max      3984.99
# Name: diff, dtype: float64

# %%
# kicking out outliers by quartiles
# calculate the quartiles
Q1 = orders_diff["diff"].quantile(0.25)
Q3 = orders_diff["diff"].quantile(0.75)

# calculate the interquartile range
IQR = Q3-Q1

# filter the DataFrame to include only "non-outliers"
diff_no_outliers_df = orders_diff.loc[(orders_diff["diff"] >= (Q1 - 1.5*IQR)) & (orders_diff["diff"] <= (Q3 + 1.5*IQR))]

# %%
diff_no_outliers_df.describe()
# Out:
#        order_id                   created_date  total_paid  unit_price_total  \
# count  44651.00                          44651    44651.00          44651.00
# mean  415140.18  2017-09-12 14:29:35.345031424      333.07            329.31
# min   241423.00            2017-01-01 01:51:47        2.82              2.49
# 25%   362869.50            2017-06-10 20:26:20       49.98             45.88
# 50%   418045.00            2017-10-28 13:26:36      109.80            104.99
# 75%   470832.50     2017-12-26 00:17:39.500000      322.99            319.00
# max   527112.00            2018-03-14 12:03:52    13387.78          13387.77
# std    65716.27                            NaN      618.06            618.86
#
#           diff
# count 44651.00
# mean      3.76
# min      -5.00
# 25%       0.00
# 50%       4.99
# 75%       6.99
# max      16.97
# std       2.91

# %%
# now we remove this from the original tables both orders and orderlines

normal_diff_list = list(diff_no_outliers_df["order_id"])

# %%
orderlines_cl = orderlines_cl.loc[orderlines_cl["id_order"].isin(normal_diff_list), :]
orders_cl = orders_diff.loc[orders_diff["order_id"].isin(normal_diff_list), :]
orderlines_cl.id_order.nunique() == orders_cl.order_id.nunique()
# Out:
# True

# %%
orders_cl["diff"] # these are the shipping costs
# Out:
# 0       6.99
# 1       4.99
# 2       6.99
# 3       0.00
# 4       6.99
#         ...
# 45374   4.99
# 45375   4.99
# 45376   4.99
# 45377   4.99
# 45378   4.99
# Name: diff, Length: 44651, dtype: float64

# %%
# adding categories to the products table using both regex and using some of the information in corrupted column type

# %%
category_type_df = products_cl.copy()

# %%
# after exploring the column type: the last 4 digits always explain a broader category (eg iPhones).
# When there is more than 4 digits, the numbers in front explain a subcategory (eg iPhone 6)
# I therefore will only work with the last 4 digits of each string.

# %%
# fixing the type column by replacing exponentials
category_type_df.loc[category_type_df["type"].str.contains("\+", na=False), "type"] = category_type_df["type"].str.replace(",", ".")
category_type_df.loc[category_type_df["type"].str.contains("\+", na=False), "type"] = category_type_df["type"].str.replace("E+", "e")
category_type_df.loc[category_type_df["type"].str.contains("\+", na=False), "type"] = category_type_df["type"].str.replace("\+", "")

# %%
category_type_df["type"] = category_type_df["type"].astype(float)

# %%
category_type_df["type"] = category_type_df["type"].fillna(0)

# %%
category_type_df["type"] = category_type_df["type"].astype(int)

# %%
category_type_df["type"] = category_type_df["type"].astype(str)

# %%
category_type_df["short_type"] = category_type_df["type"].str[-4:]

# %%
category_type_df["short_type"].unique()
# Out:
# array(['8696', '5401', '1387', '1230', '1364', '1325', '5384', '1334',
#        '5399', '5403', '5397', '5395', '1216', '5400', '0000', '1276',
#        '5404', '1296', '1229', '1404', '1405', '4259', '1282', '1424',
#        '9094', '0', '5406', '0142', '0230', '1715', '5405', '5398',
#        '5407', '2062', '1280', '1433', '1515', '5720', '1298', '1392',
#        '1231', '1375', '1714', '1416', '1434', '2425', '2434', '2449',
#        '1716', '5185', '2158', '1859', '2282'], dtype=object)

# %%
category_type_df[category_type_df.type=="0"] # 47 missing values
# Out:
#              sku                                               name  \
# index
# 307      SAN0017       SanDisk Cruzer Edge USB 2.0 Flash Drive 16GB
# 530      SAN0026    SanDisk Extreme Cruzer 16GB USB 3.0 Flash Drive
# 798      APP0675                    Apple iPhone 5S 32GB Space Gray
# 1193     APP0823                         Apple iPhone 6 16GB Silver
# 1199     APP0829                    Apple iPhone 6 Plus 16GB Silver
# 1200     APP0822                     Apple iPhone 6 16GB Space Gray
# 1201     APP0825                     Apple iPhone 6 64GB Space Gray
# 1202     APP0826                         Apple iPhone 6 64GB Silver
# 1203     APP0828                Apple iPhone 6 Plus 16GB Space Gray
# 1280     APP0856                          Apple iPhone 6 128GB Gold
# 1281     APP0857                Apple iPhone 6 Plus 64GB Space Gray
# 1282     APP0858                    Apple iPhone 6 Plus 64GB Silver
# 1283     APP0860               Apple iPhone 6 Plus 128GB Space Gray
# 1759     PAC0602               Pack Synology DS1815 + + 40TB WD Red
# 1899     SAN0035       SanDisk Ultra 16GB SDHC Memory Card Class 10
# 3016     APP1166                        Apple iPhone 6S 16GB Silver
# 3055     ELG0014                           Elgato Video Capture Mac
# 3090     APP1185                Apple iPhone 6S Plus 64GB Rose Gold
# 3106     APP1167                    Apple iPhone 6S 16GB Space Gray
# 3107     APP1169                     16GB Apple iPhone 6S Rose Gold
# 3108     APP1170                        Apple iPhone 6S 64GB Silver
# 3110     APP1171                    Apple iPhone 6S 64GB Space Gray
# 3112     APP1172                          Apple iPhone 6S 64GB Gold
# 3114     APP1173                     64GB Apple iPhone 6S Rose Gold
# 3116     APP1178                   Apple iPhone 6S Plus 16GB Silver
# 3117     APP1179               Apple iPhone 6S Plus 16GB Space Gray
# 3118     APP1180                     Apple iPhone 6S Plus 16GB Gold
# 3119     APP1181                Apple iPhone 6S Plus 16GB Rose Gold
# 3120     APP1182                   Apple iPhone 6S Plus 64GB Silver
# 3121     APP1183               Apple iPhone 6S Plus 64GB Space Gray
# 3122     APP1184                     Apple iPhone 6S Plus 64GB Gold
# 3123     APP1186                  Apple iPhone 6s Plus 128GB Silver
# 3124     APP1187              Apple iPhone 6s Plus 128GB Space Gray
# 3125     APP1188                    Apple iPhone 6s Plus 128GB Gold
# 3126     APP1189               Apple iPhone 6s Plus 128GB Rose Gold
# 3138     APP1168                          Apple iPhone 6S 16GB Gold
# 10864    APP1202                    Apple iPad Wi-Fi 32GB Pro Plata
# 11766    APP1478                           Apple iPhone 16GB Silver
# 11767    APP1479                             Apple iPhone 16GB Gold
# 11768    APP1480                        Apple iPhone 16GB Rose Gold
# 11770    APP1482                           Apple iPhone 64GB Silver
# 11771    APP1483                             Apple iPhone 64GB Gold
# 15932    PAC2056  Second hand - Apple Mac mini Core 2 Duo 226Ghz...
# 18741  GTE0093-A  Open - G-Technology G-DRIVE HDD 7200rpm 4TB Th...
# 18822    DOD0010   Dodocool Sports Wireless Stereo Headphones Black
# 19092  SYN0173-A      Open - Synology DS218 + NAS server Mac and PC
# 19185    RIN0017                                    Chime Bell Ring
#
#                                                     desc   price  promo_price  \
# index
# 307                         Pendrive USB 2.0 Mac and PC.    8.00         5.99
# 530             USB 3.0 flash drive 16GB USB Mac and PC.   22.00        20.99
# 798                New Free iPhone 5S 32GB (ME435Y / A).  559.00       399.00
# 1193               New iPhone 6 16GB Free (MG482QL / A).  639.00       639.00
# 1199           New iPhone 6 Plus 16G Free (MGA92QL / A).  749.00       749.00
# 1200               New iPhone 6 16GB Free (MG472QL / A).  639.00       639.00
# 1201               New iPhone 6 64GB Free (MG4F2QL / A).  749.00       749.00
# 1202               New iPhone 6 64GB Free (MG4H2QL / A).  749.00       750.33
# 1203          New 16GB iPhone 6 Plus Free (MGA82QL / A).  749.00       749.00
# 1280              New Free iPhone 6 128GB (MG4E2QL / A).  899.00       898.99
# 1281          New iPhone 6 Plus 64GB Free (MGAH2QL / A).  859.00       859.00
# 1282          New 64GB iPhone 6 Plus Free (MGAJ2QL / A).  859.00       859.00
# 1283             iPhone 6 Plus 128GB Free (MGAC2QL / A).  999.00       799.99
# 1759               Pack Synology DS1815 + + 40TB WD Red. 3059.99      2560.99
# 1899                              16GB SDHC memory card.   14.00         7.09
# 3016                           New 16GB iPhone 6S Libre.  749.00       749.00
# 3055             Mac USB analog video recorder hardware.   99.95        96.99
# 3090                       New iPhone 6S Plus 64GB Free.  969.00       969.00
# 3106                           New 16GB iPhone 6S Libre.  749.00       749.00
# 3107                           New 16GB iPhone 6S Libre.  749.00       749.00
# 3108                           New 64GB iPhone 6S Libre.  859.00       859.00
# 3110                           New 64GB iPhone 6S Libre.  859.00       860.33
# 3112                           New 64GB iPhone 6S Libre.  859.00       859.00
# 3114                           New 64GB iPhone 6S Libre.  859.00       859.00
# 3116                       New iPhone 6S Plus 16GB Free.  859.00       859.00
# 3117                       New iPhone 6S Plus 16GB Free.  859.00       859.00
# 3118                       New iPhone 6S Plus 16GB Free.  859.00       859.00
# 3119                       New iPhone 6S Plus 16GB Free.  859.00       859.00
# 3120                       New iPhone 6S Plus 64GB Free.  969.00       969.00
# 3121                       New iPhone 6S Plus 64GB Free.  969.00       969.00
# 3122                       New iPhone 6S Plus 64GB Free.  969.00       969.00
# 3123                     New iPhone 6s Plus 128GB Libre.  749.00       734.00
# 3124                     New iPhone 6s Plus 128GB Libre.  749.00       734.00
# 3125                     New iPhone 6s Plus 128GB Libre.  749.00       734.00
# 3126                     New iPhone 6s Plus 128GB Libre.  749.00       734.00
# 3138                           New 16GB iPhone 6S Libre.  749.00       749.00
# 10864                           Pro New iPad 32GB Wi-Fi.  899.00       902.81
# 11766               New iPhone SE with 4 inch 16GB free.  489.00       490.33
# 11767               New iPhone SE with 4 inch 16GB free.  489.00       490.33
# 11768               New iPhone SE with 4 inch 16GB free.  489.00       490.33
# 11770       New iPhone SE with 4-inch screen 64 free GB.  549.00       550.33
# 11771       New iPhone SE with 4-inch screen 64 free GB.  549.00       550.33
# 15932  Computer Refurbished Mac mini Core i2 226GHz |...  599.00       329.00
# 18741  Hard disk refitted with 2 USB 3 and Thunderbol...  423.99       292.35
# 18822  Wireless stereo headphones with remote control...   24.99        21.99
# 19092  NAS server storage refitted comprehensive spec...  344.99       330.92
# 19185  Chime bell with free Wi-Fi to amplify your not...  350.00       350.00
#
#        in_stock type decimals  len fixed_promo    new  new_promo  discount  \
# index
# 307           0    0        8    1       59895   5.99       5.99      2.01
# 530           0    0       22    2      209935  20.99      20.99      1.01
# 798           0    0      559    3     3989975 399.00     399.00    160.00
# 1193          0    0      639    3      639001 639.00     639.00      0.00
# 1199          0    0      749    3     7490021 749.00     749.00      0.00
# 1200          0    0      639    3      639001 639.00     639.00      0.00
# 1201          0    0      749    3     7490021 749.00     749.00      0.00
# 1202          0    0      749    3     7503331 750.33     750.33     -1.33
# 1203          0    0      749    3     7490021 749.00     749.00      0.00
# 1280          0    0      899    3     8989937 898.99     898.99      0.01
# 1281          0    0      859    3     8590032 859.00     859.00      0.00
# 1282          0    0      859    3     8590032 859.00     859.00      0.00
# 1283          0    0      999    3     7999915 799.99     799.99    199.01
# 1759          0    0     3059    4      256099    NaN        NaN    499.00
# 1899          0    0       14    2       70906  70.91      70.91      6.91
# 3016          0    0      749    3     7489997 749.00     749.00      0.00
# 3055          0    0       99    2      969936  96.99      96.99      2.96
# 3090          0    0      969    3     9689995 969.00     969.00      0.00
# 3106          0    0      749    3     7489997 749.00     749.00      0.00
# 3107          0    0      749    3     7489997 749.00     749.00      0.00
# 3108          0    0      859    3     8589996 859.00     859.00      0.00
# 3110          0    0      859    3     8603306 860.33     860.33     -1.33
# 3112          0    0      859    3     8589996 859.00     859.00      0.00
# 3114          0    0      859    3     8589996 859.00     859.00      0.00
# 3116          0    0      859    3     8589996 859.00     859.00      0.00
# 3117          0    0      859    3     8589996 859.00     859.00      0.00
# 3118          0    0      859    3     8589996 859.00     859.00      0.00
# 3119          0    0      859    3     8589996 859.00     859.00      0.00
# 3120          0    0      969    3     9689995 969.00     969.00      0.00
# 3121          0    0      969    3     9689995 969.00     969.00      0.00
# 3122          0    0      969    3     9689995 969.00     969.00      0.00
# 3123          0    0      749    3     7340005 734.00     734.00     15.00
# 3124          0    0      749    3     7340005 734.00     734.00     15.00
# 3125          0    0      749    3     7340005 734.00     734.00     15.00
# 3126          0    0      749    3     7340005 734.00     734.00     15.00
# 3138          0    0      749    3     7489997 749.00     749.00      0.00
# 10864         0    0      899    3     9028113 902.81     902.81     -3.81
# 11766         0    0      489    3     4903307 490.33     490.33     -1.33
# 11767         0    0      489    3     4903307 490.33     490.33     -1.33
# 11768         0    0      489    3     4903307 490.33     490.33     -1.33
# 11770         0    0      549    3      550331 550.33     550.33     -1.33
# 11771         0    0      549    3      550331 550.33     550.33     -1.33
# 15932         0    0      599    3         329    NaN        NaN    270.00
# 18741         0    0      423    3     2923459 292.35     292.35    131.64
# 18822         1    0       24    2      219899  21.99      21.99      3.00
# 19092         0    0      344    3     3309166 330.92     330.92     14.07
# 19185         0    0      350    3      350005    NaN        NaN      0.00
#
#       short_type
# index
# 307            0
# 530            0
# 798            0
# 1193           0
# 1199           0
# 1200           0
# 1201           0
# 1202           0
# 1203           0
# 1280           0
# 1281           0
# 1282           0
# 1283           0
# 1759           0
# 1899           0
# 3016           0
# 3055           0
# 3090           0
# 3106           0
# 3107           0
# 3108           0
# 3110           0
# 3112           0
# 3114           0
# 3116           0
# 3117           0
# 3118           0
# 3119           0
# 3120           0
# 3121           0
# 3122           0
# 3123           0
# 3124           0
# 3125           0
# 3126           0
# 3138           0
# 10864          0
# 11766          0
# 11767          0
# 11768          0
# 11770          0
# 11771          0
# 15932          0
# 18741          0
# 18822          0
# 19092          0
# 19185          0

# %%
category_type_df.loc[category_type_df.type.str.contains("000"), "short_type"] = category_type_df["type"].str[:4]

# %%
category_type_df["short_type"] = category_type_df["short_type"].astype(int)

# %%
category_type_df["short_type"].nunique() # still 64 remaining categories
# Out:
# 64

# %%
# most sold categories sorted after type
category_type_df.groupby("short_type").count().nlargest(10, "sku")
# Out:
#              sku  name  desc  price  promo_price  in_stock  type  decimals  \
# short_type
# 5397        2060  2060  2059   2060         2060      2060  2060      2060
# 5403        1835  1835  1835   1835         1835      1835  1835      1835
# 1298         820   820   818    820          820       820   820       820
# 5404         481   481   480    481          481       481   481       481
# 1282         373   373   373    373          373       373   373       373
# 5395         276   276   276    276          276       276   276       276
# 5740         247   247   247    247          247       247   247       247
# 2158         229   229   229    229          229       229   229       229
# 1716         221   221   221    221          221       221   221       221
# 1364         218   218   218    218          218       218   218       218
#
#              len  fixed_promo   new  new_promo  discount
# short_type
# 5397        2060         2060  1878       1878      2060
# 5403        1835         1835  1582       1582      1835
# 1298         820          820   697        697       820
# 5404         481          481   410        410       481
# 1282         373          373   353        353       373
# 5395         276          276   255        255       276
# 5740         247          247   240        240       247
# 2158         229          229   228        228       229
# 1716         221          221   190        190       221
# 1364         218          218   197        197       218

# %%
category_type_df[category_type_df["short_type"] == 5403] # cases and protectors
# Out:
#            sku                                               name  \
# index
# 15     MOS0021               Clearguard Moshi MacBook Pro and Air
# 18     MUV0009    Muvit Back Clear Case iPhone 4 / 4S Transparent
# 37     GRT0196  Griffin Survivor Extreme-Duty Case iPad 2 3 an...
# 38     MUV0023  Extreme Muvit iPhone and iPod BikeMount sleeve...
# 46     TWS0026  Twelve South BookBook MacBook Air sleeve 11 "b...
# ...        ...                                                ...
# 19279  MMW0012  My MW Case MacBook Pro 13 "(Late 2016) Blue Sa...
# 19280  MMW0013  My MW Case MacBook Pro 13 "(Late 2016) White S...
# 19281  MMW0016       My MW Case MacBook Pro 13 "(Late 2016) Black
# 19282  MMW0015        My MW Case MacBook Pro 13 "(Late 2016) Gray
# 19288  AP20649  Like new - Apple Leather Case iPhone Case 8/7 ...
#
#                                                     desc  price  promo_price  \
# index
# 15     Keyboard Protector MacBook Pro 13-inch Retina ...  24.95        24.99
# 18                     Case iPhone 4 / 4S polycarbonate.   9.99         7.99
# 37      IPad 2 Case 3 and 4 for extreme ultra resistant.  64.99        49.99
# 38     IPhone and iPod support sleeve waterproof App ...  35.90        16.99
# 46     Case Macbook 11 inches vintage skin with soft ...  79.99        75.00
# ...                                                  ...    ...          ...
# 19279  Avoid shock and damage to your MacBook Pro 13-...  29.99        20.99
# 19280  Avoid shock and damage to your MacBook Pro 13-...  29.99        20.99
# 19281  Avoid shock and damage to your MacBook Pro 13-...  29.99        20.99
# 19282  Avoid shock and damage to your MacBook Pro 13-...  29.99        20.99
# 19288  Reconditioned sleeve leather and microfiber Ap...  55.00        42.00
#
#        in_stock      type decimals  len fixed_promo   new  new_promo  \
# index
# 15            0  13835403       24    2      249889 24.99      24.99
# 18            0  11865403        9    1        7986   NaN        NaN
# 37            0  12635403       64    2      499899 49.99      49.99
# 38            0  11865403       35    2      169896 16.99      16.99
# 46            0  13835403       79    2      749958 75.00      75.00
# ...         ...       ...      ...  ...         ...   ...        ...
# 19279         0  13835403       29    2        2099   NaN        NaN
# 19280         1  13835403       29    2        2099   NaN        NaN
# 19281         1  13835403       29    2        2099   NaN        NaN
# 19282         1  13835403       29    2        2099   NaN        NaN
# 19288         0  11865403       55    2      420003 42.00      42.00
#
#        discount  short_type
# index
# 15        -0.04        5403
# 18         2.00        5403
# 37        15.00        5403
# 38        18.91        5403
# 46         4.99        5403
# ...         ...         ...
# 19279      9.00        5403
# 19280      9.00        5403
# 19281      9.00        5403
# 19282      9.00        5403
# 19288     13.00        5403
#
# [1835 rows x 14 columns]

# %%
# adding a column for the short brand name
category_type_df["brand_short"] = category_type_df["sku"].str[:3]

# %%
# cleaning the unnecessary columns
category_type_df.drop(columns=["decimals", "len", "fixed_promo", "new", "new_promo"],inplace=True)

# %%
# we will keep working with these categories in the future.
category_type_df["category"] = "other"
category_type_df.loc[category_type_df['desc'].str.contains('chil|kid|toy|game', case=False), "category"] = "games/toys"
category_type_df.loc[category_type_df['desc'].str.contains('fit|cardio|sport|activ|Sphygmomanometer|measuring|run|health', case=False), "category"] = "sport"
category_type_df.loc[category_type_df['desc'].str.contains('music|loud|microph|head|dj|cd|dvd|speaker', case=False), "category"] = "music"
category_type_df.loc[category_type_df['desc'].str.contains('charge|adapter|cable|wire|batter|power|connect|transformer|protector|usb|cable', case=False), "category"] = "power"
category_type_df.loc[category_type_df['name'].str.contains('case', case=False), "category"] = "cases"
category_type_df.loc[category_type_df[('desc')].str.contains('care|protect', case=False), "category"] = "care"
category_type_df.loc[category_type_df[('name')].str.contains('care|protect', case=False), "category"] = "care"
category_type_df.loc[category_type_df['name'].str.contains('keyboard|mouse|pen|Toolkit', case=False), "category"] = "computer accessories"
category_type_df.loc[category_type_df['name'].str.startswith('Apple Macbook'), "category"] = 'Macbook'
category_type_df.loc[category_type_df['name'].str.startswith('Apple iPhone 8|Apple iPhone 7|Apple iPhone SE|Apple iPhone 3|Apple iPhone 6|Apple iPhone 7'), "category"] = 'iPhone'
category_type_df.loc[category_type_df['name'].str.contains('watch', case=False), "category"] = "watch"
category_type_df.loc[(category_type_df['sku'].str.startswith('AP')) & (category_type_df['price'] > 300), 'category'] = "iPad/Mac/Tablet"
category_type_df.loc[category_type_df['name'].str.startswith('Apple iMac 2'),'category'] = "iPad/Mac/Tablet"
category_type_df.loc[category_type_df['name'].str.contains('tablet', case=False), "category"] = "iPad/Mac/Tablet"
category_type_df.loc[(category_type_df['desc'].str.contains('server')) & (category_type_df['name'].str.contains('server')), "category"] = "server"
category_type_df.loc[category_type_df['desc'].str.contains('monitor|display', case=False), "category"] = "monitor"
category_type_df.loc[category_type_df['desc'].str.contains('memory|drive', case=False), "category"] = "memory"
category_type_df.loc[category_type_df['desc'].str.contains('router|satellite', case=False), "category"] = "routers"
category_type_df.loc[category_type_df['desc'].str.contains('camera', case=False), "category"] = "cameras"
category_type_df.loc[category_type_df['desc'].str.contains('bag|Backpack', case=False), "category"] = 'bags'
category_type_df.loc[category_type_df['desc'].str.contains('expansion', case=False), "category"] = 'expansion'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 2
#       1 # we will keep working with these categories in the future.
# ----> 2 category_type_df.loc[category_type_df['desc'].str.contains('chil|kid|toy|game', case=False), "category"] = "games/toys"
#       3 category_type_df.loc[category_type_df['desc'].str.contains('fit|cardio|sport|activ|Sphygmomanometer|measuring|run|health', case=False), "category"] = "sport"
#       4 category_type_df.loc[category_type_df['desc'].str.contains('music|loud|microph|head|dj|cd|dvd|speaker', case=False), "category"] = "music"
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:845, in _LocationIndexer.__setitem__(self, key, value)
#     843 else:
#     844     key = com.apply_if_callable(key, self.obj)
# --> 845 indexer = self._get_setitem_indexer(key)
#     846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:710, in _LocationIndexer._get_setitem_indexer(self, key)
#     707 if isinstance(key, tuple):
#     708     with suppress(IndexingError):
#     709         # suppress "Too many indexers"
# --> 710         return self._convert_tuple(key)
#     712 if isinstance(key, range):
#     713     # GH#45479 test_loc_setitem_range_key
#     714     key = list(key)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:927, in _LocationIndexer._convert_tuple(self, key)
#     923 @final
#     924 def _convert_tuple(self, key: tuple) -> tuple:
#     925     # Note: we assume _tupleize_axis_indexer has been called, if necessary.
#     926     self._validate_key_length(key)
# --> 927     keyidx = [self._convert_to_indexer(k, axis=i) for i, k in enumerate(key)]
#     928     return tuple(keyidx)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:927, in <listcomp>(.0)
#     923 @final
#     924 def _convert_tuple(self, key: tuple) -> tuple:
#     925     # Note: we assume _tupleize_axis_indexer has been called, if necessary.
#     926     self._validate_key_length(key)
# --> 927     keyidx = [self._convert_to_indexer(k, axis=i) for i, k in enumerate(key)]
#     928     return tuple(keyidx)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1422, in _LocIndexer._convert_to_indexer(self, key, axis)
#    1419 if is_iterator(key):
#    1420     key = list(key)
# -> 1422 if com.is_bool_indexer(key):
#    1423     key = check_bool_indexer(labels, key)
#    1424     return key
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/common.py:134, in is_bool_indexer(key)
#     130     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     131     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
#     132         # Don't raise on e.g. ["A", "B", np.nan], see
#     133         #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 134         raise ValueError(na_msg)
#     135     return False
#     136 return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
# adding this category defined by short_type
category_type_df.loc[category_type_df["short_type"]==1716, "category"] = "iPhone"

# %%
# renaming columns
category_type_df.rename(columns = {"long":"brand"}, inplace=True)

# %%
category_type_df["sku"].nunique(), orderlines_cl["sku"].nunique() # not all products on products table have been sold
# Out:
# (10157, 5808)

# %%
# adding a discount column
category_name_df["discount"] = category_name_df["price"] - category_name_df["promo_price"]

# %%
orderlines_cl["id_order"].nunique() == orders_cl["order_id"].nunique()
# Out:
# True

# %%
category_type_df.to_parquet("products_qu.parquet")
orders_cl.to_csv("orders_qu.csv")
orderlines_cl.to_parquet("orderlines_qu.parquet")
